# %% [markdown]
# 1) Is it permissible to use several import statements to import the same module? What would the goal be? Can you think of a situation where it would be beneficial?

# %%
#We had used the same module two times. To make the code small and handy we import it as shortform.
#When we import two times according to the user who use it will understood well.
#It is used in multiple scenarios.

# %%
import pandas

# %%
import pandas as pd

# %%
df1=pd.read_csv('HDFCBANK-Copy1.csv')

# %%
df1
# Out:
#             Date    Symbol Series  Prev Close     Open     High      Low  \
# 0     2000-01-03  HDFCBANK     EQ      157.40   166.00   170.00   166.00
# 1     2000-01-04  HDFCBANK     EQ      170.00   182.00   183.45   171.00
# 2     2000-01-05  HDFCBANK     EQ      173.80   170.00   173.90   165.00
# 3     2000-01-06  HDFCBANK     EQ      166.95   168.00   170.00   165.30
# 4     2000-01-07  HDFCBANK     EQ      168.30   162.15   171.00   162.15
# ...          ...       ...    ...         ...      ...      ...      ...
# 5301  2021-04-26  HDFCBANK     EQ     1414.15  1413.00  1429.00  1402.75
# 5302  2021-04-27  HDFCBANK     EQ     1404.80  1407.25  1442.00  1404.80
# 5303  2021-04-28  HDFCBANK     EQ     1438.70  1436.25  1479.00  1431.00
# 5304  2021-04-29  HDFCBANK     EQ     1476.80  1486.20  1503.65  1461.00
# 5305  2021-04-30  HDFCBANK     EQ     1472.50  1445.00  1453.80  1407.50
#
#          Last    Close     VWAP    Volume      Turnover    Trades  \
# ...

# %%
df2=pandas.read_csv('HDFCBANK-Copy1.csv')

# %%
df2
# Out:
#             Date    Symbol Series  Prev Close     Open     High      Low  \
# 0     2000-01-03  HDFCBANK     EQ      157.40   166.00   170.00   166.00
# 1     2000-01-04  HDFCBANK     EQ      170.00   182.00   183.45   171.00
# 2     2000-01-05  HDFCBANK     EQ      173.80   170.00   173.90   165.00
# 3     2000-01-06  HDFCBANK     EQ      166.95   168.00   170.00   165.30
# 4     2000-01-07  HDFCBANK     EQ      168.30   162.15   171.00   162.15
# ...          ...       ...    ...         ...      ...      ...      ...
# 5301  2021-04-26  HDFCBANK     EQ     1414.15  1413.00  1429.00  1402.75
# 5302  2021-04-27  HDFCBANK     EQ     1404.80  1407.25  1442.00  1404.80
# 5303  2021-04-28  HDFCBANK     EQ     1438.70  1436.25  1479.00  1431.00
# 5304  2021-04-29  HDFCBANK     EQ     1476.80  1486.20  1503.65  1461.00
# 5305  2021-04-30  HDFCBANK     EQ     1472.50  1445.00  1453.80  1407.50
#
#          Last    Close     VWAP    Volume      Turnover    Trades  \
# ...

# %% [markdown]
# 2) What are some of a module's characteristics? (Name at least one.)

# %%
# A module is a file containing python definitions and statements. 
# A module can define functions, classes & variables.
# Some of the important modules are Numpy,pandas,tkinter, matplotlib,plotly,sklearn etc...

# %% [markdown]
# 3)  Circular importing, such as when two modules import each other, can lead to dependencies and bugs that aren't visible. How can you go about creating a program that avoids mutual importing?

# %%
# When two modules depend on each other it creates circular importing problem.
# To get rid of this thing we can merge both modules and create functions for both the things and use it.
# Else just import the module and with the help of object use the in-built functions in the Module

# %% [markdown]
# 4) Why is  _ _all_ _ in Python?

# %% [markdown]
# > * The variable __all__ is a list of public objects that module interpreted by import *
# * It imports all the names what are defined that package.
# * This can be used another as " from * import name1 "

# %% [markdown]
# 5)  In what situation is it useful to refer to the _ _name_ _ attribute or the string '_ _main_ _'?

# %% [markdown]
# > * If you import the script as a module in another script, the __name__ is set to the name of the script/module.
# * Modules are reusable.

# %% [markdown]
# 6) What are some of the benefits of attaching a program counter to the RPN interpreter application, which interprets an RPN script line by line?

# %% [markdown]
# > * Reverse Polish Notation Interpreter is a mathematical notation where operators preceeds their operands
# * This is due to expressions are not parenthesized and smaller key strokes
# * if we install rpncall we can make use of RPN Notation

# %% [markdown]
# 7) What are the minimum expressions or statements (or both) that you'd need to render a basic programming language like RPN primitive but complete— that is, capable of carrying out any computerised task theoretically possible?

# %% [markdown]
# > * For each and every expression we need to create a function.
# * There are arithmetic operators like + , - , / , *
# * We need to create function for each symbol and loop through the statement passed
